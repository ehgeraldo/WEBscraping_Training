# %% [markdown]
# # DOCUMENTATION

# %%
#https://www.crummy.com/software/BeautifulSoup/bs4/doc/

# %% [markdown]
# # PIP INSTALL

# %%
pip install bs4
# Out:
# ...
#      |████████████████████████████████| 115 kB 3.4 MB/s eta 0:00:01
# ...
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1272 sha256=c1fce266756b55b120b0574e2c7880652caedc2632e2daa32d3265e96d31562d
#   Stored in directory: /home/ehgeraldo/.cache/pip/wheels/73/2b/cb/099980278a0c9a3e57ff1a89875ec07bfa0b6fcbebb9a8cad3
# Successfully built bs4
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # IMPORTS

# %%
from bs4 import BeautifulSoup

import requests

from IPython.display import Image
# Out:
#   File "/tmp/ipykernel_4261/2491499033.py", line 6
#     Image( /image/'image_00.png' )
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# # WEBSCRAPING

# %%
Image( 'image_00.png' )

# %%
# URL que desejamos informações
url = 'https://www2.hm.com/en_us/men/products/jeans.html'

# Dicionario => para completar a requisição ao website
headers = {'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5)AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}

# Efetua a requisição ao site desejado
page = requests.get( url, headers=headers )

# %%
soup = BeautifulSoup( page.text, 'html.parser')

# %%
# Todo html da página 
soup
# Out:
# <!DOCTYPE HTML>
#
# <html class="no-js en-us" is-in-aem="false" lang="en-US" ng-app="hmApp">
# <head>
# <script data-dtconfig="rid=RID_-1928280405|rpid=1157779550|domain=hmgroup.tech|reportUrl=/rb_58096d71-709f-4335-a959-44a125e69dd3|app=7a6f08f8d839fa96|rcdec=1209600000|featureHash=ICA27SVfgjoqru|vcv=2|rdnt=1|uxrgce=1|bp=2|srmcrv=10|cuc=gbmnxyo0|mel=100000|dpvc=1|lastModification=1629115662936|dtVersion=10215210506134511|srmcrl=1|tp=500,50,0,1|uxdcw=1500|vs=2|agentUri=/ruxitagentjs_ICA27SVfgjoqru_10215210506134511.js" src="/ruxitagentjs_ICA27SVfgjoqru_10215210506134511.js" type="text/javascript"></script><link href="https://s1-cdn.hm.com" rel="dns-prefetch"/>
# <link crossorigin="" href="https://s1-cdn.hm.com" rel="preconnect"/>
# <link href="https://tags.tiqcdn.com" rel="dns-prefetch"/>
# <link crossorigin="" href="https://tags.tiqcdn.com" rel="preconnect"/>
# <link href="https://lp2.hm.com" rel="dns-prefetch"/>
# <link crossorigin="" href="https://lp2.hm.com" rel="preconnect"/>
# ...

# %%
Image( 'image_01.png' )

# %%
# encontra o primeiro registro (elemento)

products = soup.find( 'ul', class_='products-listing small' )

# %%
products
# Out:
# <ul class="products-listing small">
# <li class="product-item">
# <article class="hm-product-item" data-articlecode="0636207011" data-category="" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0636207011'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDYzNjIwN19ncm91cF8wMTFfZW5fdXM7MDYzNjIwNzAxMV9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3OTs','0636207011');">
# <div class="image-container">
# <a class="item-link" href="/en_us/productpage.0636207011.html" title="Slim Jeans">
# ...

# %%
product_list = products.find_all( 'article', class_='hm-product-item')
product_list
# Out:
# [<article class="hm-product-item" data-articlecode="0636207011" data-category="" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0636207011'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDYzNjIwN19ncm91cF8wMTFfZW5fdXM7MDYzNjIwNzAxMV9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3OTs','0636207011');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.0636207011.html" title="Slim Jeans">
# ...

# %%
Image( 'image_02.png' )

# %%
type( product_list )
# Out:
# bs4.element.ResultSet

# %%
# código único para os produtos 

product_list[1].get( 'data-articlecode' )
product_list[2].get( 'data-articlecode' )
# Out:
# '0636207001'

# %%
Image( 'image_03.png' )

# %%
# exemplo de aplicação de um for em uma linha
[ i*10 for i in range(1,10) ]
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80, 90]

# %%
# Aplicar um for para toda a lista

product_id = [ p.get( 'data-articlecode' ) for p in product_list ]

# %%
# Retorna os id dos produtos da lista ( data-articlecode )

product_id
# Out:
# ['0636207011',
#  '0720504010',
#  '0636207001',
#  '0720504013',
#  '0814631006',
#  '0690449043',
#  '1004476002',
#  '1008549006',
#  '1013317001',
#  '0985159005',
#  '1008549004',
#  '0811993021',
#  '0998599006',
#  '0811993028',
#  '0998599005',
#  '0811993003',
#  '0811993036',
#  '1008549001',
#  '1004199003',
#  '0875105001',
#  '0811993031',
#  '0875105003',
#  '0811993037',
#  '0875105002',
#  '0690449022',
#  '0427159006',
#  '0730863005',
#  '0636207010',
#  '0636207006',
#  '0720504008',
#  '0985159001',
#  '0985197001',
#  '1004199001',
#  '0985159003',
#  '0985159002',
#  '0985159004']

# %%
product_category = [ p.get( 'data-category' )for p in product_list ]

# %%
# Retorna a categoria da lista (data-category)
product_category
# Out:
# ['',
#  'men_jeans_skinny',
#  '',
#  'men_jeans_skinny',
#  'men_jeans_slim',
#  'men_jeans_ripped',
#  '',
#  'men_jeans_regular',
#  '',
#  'men_jeans_skinny',
#  'men_jeans_regular',
#  'men_jeans_regular',
#  'men_jeans_regular',
#  'men_jeans_regular',
#  'men_jeans_regular',
#  'men_jeans_regular',
#  'men_jeans_regular',
#  'men_jeans_regular',
#  '',
#  'men_jeans_relaxed',
#  'men_jeans_regular',
#  'men_jeans_relaxed',
#  'men_jeans_regular',
#  'men_jeans_relaxed',
#  'men_jeans_ripped',
#  'men_jeans_ripped',
#  '',
#  '',
#  '',
#  'men_jeans_skinny',
#  'men_jeans_skinny',
#  'men_jeans_slim',
#  '',
#  'men_jeans_skinny',
#  'men_jeans_skinny',
#  'men_jeans_skinny']

# %%
products_list = products.find_all( 'a', class_='link')

# %%
products_list
# Out:
# [<a class="link" href="/en_us/productpage.0636207011.html">Slim Jeans</a>,
#  <a class="link" href="/en_us/productpage.0720504010.html">Skinny Jeans</a>,
#  <a class="link" href="/en_us/productpage.0636207001.html">Slim Jeans</a>,
#  <a class="link" href="/en_us/productpage.0720504013.html">Skinny Jeans</a>,
#  <a class="link" href="/en_us/productpage.0814631006.html">Freefit® Slim Jeans</a>,
#  <a class="link" href="/en_us/productpage.0690449043.html">Skinny Jeans</a>,
#  <a class="link" href="/en_us/productpage.1004476002.html">Freefit® Slim Jeans</a>,
#  <a class="link" href="/en_us/productpage.1008549006.html">Regular Jeans</a>,
#  <a class="link" href="/en_us/productpage.1013317001.html">Hybrid Regular Tapered Joggers</a>,
#  <a class="link" href="/en_us/productpage.0985159005.html">Skinny Jeans</a>,
#  <a class="link" href="/en_us/productpage.1008549004.html">Regular Jeans</a>,
#  <a class="link" href="/en_us/productpage.0811993021.html">Regular Jeans</a>,
# ...

# %%
products_list[0].get_text()
products_list[1].get_text()
# Out:
# 'Skinny Jeans'

# %%
# Para extrair os nomes dos produtos da lista

products_name = [ p.get_text() for p in products_list ]

# %%
products_name
# Out:
# ['Slim Jeans',
#  'Skinny Jeans',
#  'Slim Jeans',
#  'Skinny Jeans',
#  'Freefit® Slim Jeans',
#  'Skinny Jeans',
#  'Freefit® Slim Jeans',
#  'Regular Jeans',
#  'Hybrid Regular Tapered Joggers',
#  'Skinny Jeans',
#  'Regular Jeans',
#  'Regular Jeans',
#  'Regular Jeans',
#  'Regular Jeans',
#  'Regular Jeans',
#  'Regular Jeans',
#  'Regular Jeans',
#  'Regular Jeans',
#  'Skinny Cropped Jeans',
#  'Relaxed Jeans',
#  'Regular Jeans',
#  'Relaxed Jeans',
#  'Regular Jeans',
#  'Relaxed Jeans',
#  'Skinny Jeans',
#  'Trashed Skinny Jeans',
#  'Skinny Jeans',
#  'Slim Jeans',
#  'Slim Jeans',
#  'Skinny Jeans',
#  'Skinny Jeans',
#  'Slim Jeans',
#  'Skinny Cropped Jeans',
#  'Skinny Jeans',
#  'Skinny Jeans',
#  'Skinny Jeans']

# %%
# price

product_list = products.find_all( 'span', class_='price regular' )

# %%
product_list
# Out:
# [<span class="price regular">$ 19.99</span>,
#  <span class="price regular">$ 24.99</span>,
#  <span class="price regular">$ 19.99</span>,
#  <span class="price regular">$ 24.99</span>,
#  <span class="price regular">$ 49.99</span>,
#  <span class="price regular">$ 39.99</span>,
#  <span class="price regular">$ 49.99</span>,
#  <span class="price regular">$ 19.99</span>,
#  <span class="price regular">$ 39.99</span>,
#  <span class="price regular">$ 19.99</span>,
#  <span class="price regular">$ 19.99</span>,
#  <span class="price regular">$ 29.99</span>,
#  <span class="price regular">$ 24.99</span>,
#  <span class="price regular">$ 29.99</span>,
#  <span class="price regular">$ 24.99</span>,
#  <span class="price regular">$ 29.99</span>,
#  <span class="price regular">$ 29.99</span>,
#  <span class="price regular">$ 19.99</span>,
#  <span class="price regular">$ 29.99</span>,
#  <span class="price regular">$ 29.99</span>,
#  <span class="price regular">$ 29.99</span>,
# ...

# %%
product_price = [ p.get_text() for p in product_list ]

# %%
product_price
# Out:
# ['$ 19.99',
#  '$ 24.99',
#  '$ 19.99',
#  '$ 24.99',
#  '$ 49.99',
#  '$ 39.99',
#  '$ 49.99',
#  '$ 19.99',
#  '$ 39.99',
#  '$ 19.99',
#  '$ 19.99',
#  '$ 29.99',
#  '$ 24.99',
#  '$ 29.99',
#  '$ 24.99',
#  '$ 29.99',
#  '$ 29.99',
#  '$ 19.99',
#  '$ 29.99',
#  '$ 29.99',
#  '$ 29.99',
#  '$ 29.99',
#  '$ 29.99',
#  '$ 29.99',
#  '$ 39.99',
#  '$ 39.99',
#  '$ 29.99',
#  '$ 19.99',
#  '$ 19.99',
#  '$ 24.99',
#  '$ 19.99',
#  '$ 19.99',
#  '$ 29.99',
#  '$ 19.99',
#  '$ 19.99',
#  '$ 19.99']

# %%
# 36 produtos na página

len( product_list )
# Out:
# 36
